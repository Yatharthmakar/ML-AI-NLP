# %%
import numpy as np
import seaborn as sns
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import mean_absolute_error

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
X = tips.drop("tip", axis=1)
y = tips["tip"]

# %%
X_encoded = pd.get_dummies(X, columns=["sex", "smoker", "day", "time"])

# %%
X_train_encoded, X_test_encoded, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_encoded)
X_test_scaled = scaler.transform(X_test_encoded)

# %%
model = Sequential()
model.add(Dense(8, activation='relu', input_shape=(X_train_scaled.shape[1],)))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy')

# %%
model.fit(X_train_scaled, y_train, epochs=100, batch_size=32, verbose=1)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 1s 4ms/step - loss: 2.1649
# Epoch 2/100
# 7/7 [==============================] - 0s 4ms/step - loss: 1.8985
# Epoch 3/100
# 7/7 [==============================] - 0s 4ms/step - loss: 1.6273
# Epoch 4/100
# 7/7 [==============================] - 0s 4ms/step - loss: 1.3686
# Epoch 5/100
# 7/7 [==============================] - 0s 4ms/step - loss: 1.1359
# Epoch 6/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.8926
# Epoch 7/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6611
# Epoch 8/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4335
# Epoch 9/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2107
# Epoch 10/100
# 7/7 [==============================] - 0s 3ms/step - loss: -0.0202
# Epoch 11/100
# 7/7 [==============================] - 0s 4ms/step - loss: -0.2399
# Epoch 12/100
# 7/7 [==============================] - 0s 4ms/step - loss: -0.4567
# Epoch 13/100
# 7/7 [==============================] - 0s 5ms/step - loss: -0.6720
# Epoch 14/100
# 7/7 [==============================] - 0s 4ms/step - loss: -0.8849
# Epoch 15/100
# 7/7 [==============================] - 0s 3ms/step - loss: -1.0801
# Epoch 16/100
# 7/7 [==============================] - 0s 4ms/step - loss: -1.2882
# Epoch 17/100
# 7/7 [==============================] - 0s 3ms/step - loss: -1.4826
# Epoch 18/100
# 7/7 [==============================] - 0s 3ms/step - loss: -1.6724
# Epoch 19/100
# 7/7 [==============================] - 0s 3ms/step - loss: -1.8614
# Epoch 20/100
# 7/7 [==============================] - 0s 4ms/step - loss: -2.0564
# Epoch 21/100
# 7/7 [==============================] - 0s 4ms/step - loss: -2.2447
# Epoch 22/100
# 7/7 [==============================] - 0s 4ms/step - loss: -2.4252
# Epoch 23/100
# 7/7 [==============================] - 0s 4ms/step - loss: -2.6143
# Epoch 24/100
# 7/7 [==============================] - 0s 5ms/step - loss: -2.8061
# Epoch 25/100
# 7/7 [==============================] - 0s 4ms/step - loss: -2.9826
# Epoch 26/100
# 7/7 [==============================] - 0s 3ms/step - loss: -3.1666
# Epoch 27/100
# 7/7 [==============================] - 0s 3ms/step - loss: -3.3448
# Epoch 28/100
# 7/7 [==============================] - 0s 4ms/step - loss: -3.5257
# Epoch 29/100
# 7/7 [==============================] - 0s 5ms/step - loss: -3.7015
# Epoch 30/100
# 7/7 [==============================] - 0s 4ms/step - loss: -3.8916
# Epoch 31/100
# 7/7 [==============================] - 0s 3ms/step - loss: -4.0599
# Epoch 32/100
# 7/7 [==============================] - 0s 3ms/step - loss: -4.2426
# Epoch 33/100
# 7/7 [==============================] - 0s 3ms/step - loss: -4.4301
# Epoch 34/100
# 7/7 [==============================] - 0s 3ms/step - loss: -4.6128
# Epoch 35/100
# 7/7 [==============================] - 0s 3ms/step - loss: -4.7966
# Epoch 36/100
# 7/7 [==============================] - 0s 3ms/step - loss: -4.9818
# Epoch 37/100
# 7/7 [==============================] - 0s 3ms/step - loss: -5.1815
# Epoch 38/100
# 7/7 [==============================] - 0s 3ms/step - loss: -5.3821
# Epoch 39/100
# 7/7 [==============================] - 0s 4ms/step - loss: -5.5814
# Epoch 40/100
# 7/7 [==============================] - 0s 3ms/step - loss: -5.7732
# Epoch 41/100
# 7/7 [==============================] - 0s 3ms/step - loss: -5.9691
# Epoch 42/100
# 7/7 [==============================] - 0s 3ms/step - loss: -6.1721
# Epoch 43/100
# 7/7 [==============================] - 0s 3ms/step - loss: -6.3672
# Epoch 44/100
# 7/7 [==============================] - 0s 4ms/step - loss: -6.5748
# Epoch 45/100
# 7/7 [==============================] - 0s 4ms/step - loss: -6.7647
# Epoch 46/100
# 7/7 [==============================] - 0s 3ms/step - loss: -6.9841
# Epoch 47/100
# 7/7 [==============================] - 0s 4ms/step - loss: -7.1856
# Epoch 48/100
# 7/7 [==============================] - 0s 3ms/step - loss: -7.4088
# Epoch 49/100
# 7/7 [==============================] - 0s 3ms/step - loss: -7.6193
# Epoch 50/100
# 7/7 [==============================] - 0s 3ms/step - loss: -7.8290
# Epoch 51/100
# 7/7 [==============================] - 0s 3ms/step - loss: -8.0503
# Epoch 52/100
# 7/7 [==============================] - 0s 3ms/step - loss: -8.2689
# Epoch 53/100
# 7/7 [==============================] - 0s 3ms/step - loss: -8.5021
# Epoch 54/100
# 7/7 [==============================] - 0s 3ms/step - loss: -8.7346
# Epoch 55/100
# 7/7 [==============================] - 0s 3ms/step - loss: -8.9635
# Epoch 56/100
# 7/7 [==============================] - 0s 3ms/step - loss: -9.1854
# Epoch 57/100
# 7/7 [==============================] - 0s 3ms/step - loss: -9.4242
# Epoch 58/100
# 7/7 [==============================] - 0s 3ms/step - loss: -9.6600
# Epoch 59/100
# 7/7 [==============================] - 0s 3ms/step - loss: -9.8878
# Epoch 60/100
# 7/7 [==============================] - 0s 3ms/step - loss: -10.1126
# Epoch 61/100
# 7/7 [==============================] - 0s 3ms/step - loss: -10.3445
# Epoch 62/100
# 7/7 [==============================] - 0s 3ms/step - loss: -10.5743
# Epoch 63/100
# 7/7 [==============================] - 0s 3ms/step - loss: -10.8197
# Epoch 64/100
# 7/7 [==============================] - 0s 4ms/step - loss: -11.0636
# Epoch 65/100
# 7/7 [==============================] - 0s 5ms/step - loss: -11.3059
# Epoch 66/100
# 7/7 [==============================] - 0s 4ms/step - loss: -11.5470
# Epoch 67/100
# 7/7 [==============================] - 0s 4ms/step - loss: -11.8151
# Epoch 68/100
# 7/7 [==============================] - 0s 4ms/step - loss: -12.0854
# Epoch 69/100
# 7/7 [==============================] - 0s 4ms/step - loss: -12.3558
# Epoch 70/100
# 7/7 [==============================] - 0s 4ms/step - loss: -12.6139
# Epoch 71/100
# 7/7 [==============================] - 0s 3ms/step - loss: -12.8864
# Epoch 72/100
# 7/7 [==============================] - 0s 4ms/step - loss: -13.1692
# Epoch 73/100
# 7/7 [==============================] - 0s 3ms/step - loss: -13.4335
# Epoch 74/100
# 7/7 [==============================] - 0s 3ms/step - loss: -13.7025
# Epoch 75/100
# 7/7 [==============================] - 0s 3ms/step - loss: -14.0037
# Epoch 76/100
# 7/7 [==============================] - 0s 3ms/step - loss: -14.3010
# Epoch 77/100
# 7/7 [==============================] - 0s 3ms/step - loss: -14.6037
# Epoch 78/100
# 7/7 [==============================] - 0s 4ms/step - loss: -14.9317
# Epoch 79/100
# 7/7 [==============================] - 0s 5ms/step - loss: -15.2411
# Epoch 80/100
# 7/7 [==============================] - 0s 4ms/step - loss: -15.5660
# Epoch 81/100
# 7/7 [==============================] - 0s 4ms/step - loss: -15.8952
# Epoch 82/100
# 7/7 [==============================] - 0s 4ms/step - loss: -16.2458
# Epoch 83/100
# 7/7 [==============================] - 0s 4ms/step - loss: -16.5927
# Epoch 84/100
# 7/7 [==============================] - 0s 4ms/step - loss: -16.9570
# Epoch 85/100
# 7/7 [==============================] - 0s 3ms/step - loss: -17.3030
# Epoch 86/100
# 7/7 [==============================] - 0s 3ms/step - loss: -17.6741
# Epoch 87/100
# 7/7 [==============================] - 0s 4ms/step - loss: -18.0474
# Epoch 88/100
# 7/7 [==============================] - 0s 5ms/step - loss: -18.4415
# Epoch 89/100
# 7/7 [==============================] - 0s 4ms/step - loss: -18.8355
# Epoch 90/100
# 7/7 [==============================] - 0s 3ms/step - loss: -19.1962
# Epoch 91/100
# 7/7 [==============================] - 0s 4ms/step - loss: -19.5949
# Epoch 92/100
# 7/7 [==============================] - 0s 3ms/step - loss: -20.0077
# Epoch 93/100
# 7/7 [==============================] - 0s 3ms/step - loss: -20.4077
# Epoch 94/100
# 7/7 [==============================] - 0s 3ms/step - loss: -20.8371
# Epoch 95/100
# 7/7 [==============================] - 0s 3ms/step - loss: -21.2892
# Epoch 96/100
# 7/7 [==============================] - 0s 3ms/step - loss: -21.7199
# Epoch 97/100
# 7/7 [==============================] - 0s 4ms/step - loss: -22.1876
# Epoch 98/100
# 7/7 [==============================] - 0s 5ms/step - loss: -22.6778
# Epoch 99/100
# 7/7 [==============================] - 0s 3ms/step - loss: -23.1470
# Epoch 100/100
# 7/7 [==============================] - 0s 4ms/step - loss: -23.6305

# %%
y_pred = model.predict(X_test_scaled)
mae = mean_absolute_error(y_test, y_pred)
print(f"Mean Absolute Error: {mae:.2f}")
# Out:
# 2/2 [==============================] - 0s 5ms/step
# Mean Absolute Error: 1.65
